# %%
import pandas as pd

# %%
df = pd.read_csv('Amazonbookreviews.csv')
df.head()
# Out:
#        reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      43 non-null     object
#  1   asin            43 non-null     float64
#  2   reviewername    44 non-null     object
#  3   helpful         45 non-null     int64
#  4   reviewerText    45 non-null     object
#  5   overallRating   45 non-null     float64
#  6   Summary         45 non-null     object
#  7   UnixreviewTime  0 non-null      float64
#  8   reviewTime      0 non-null      float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.3+ KB

# %%
subset2 = df[['reviewText', 'summary', 'reviewTime']]
subset2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 subset2 = df[['reviewText', 'summary', 'reviewTime']]
#       2 subset2.head()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...
