# %% [markdown]
#  Web Scrapping

# %%
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from bs4 import BeautifulSoup
import requests
URL = "https://www.ebay.com/itm/197208306396?_skw=ps5&itmmeta=01JS0YWE3WQYDHNDYGGQQKY5PX&hash=item2dea87f2dc:g:sKEAAOSwX41n~JYO&itmprp=enc%3AAQAKAAAA4FkggFvd1GGDu0w3yXCmi1cXDL%2BqzRcmpcTyslTagCfLPe%2BqJiYIoMj%2FsqhgIyKpmK8CgwA9dhXbHi9wL3sQBNHCINM0m4gCVBfcvgoePY5jjrhNaq4GAm3CoNEc9PgR3nZD%2FqrPAjJGM36QOsynmeRWX69yaSx8WU4m8uPhb7yHUm6xRRYQTbirHoGfs7u7tX6vrvRXNOLRsPcWQ2TGpuiIFw7Z%2FXDgeDwWSKC6ltJbu5ezrPZPJlZs8UyAo8g4CNwLJbsYky7FJF0s5%2FCP0vWAtV2KLN89kZ8G2k%2FYN1BJ%7Ctkp%3ABFBMruLxnshl"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
}
r = requests.get(URL, headers=headers)
print(r.content)
# Out:
# b'<!--M#s0--><!--M^s0-35 s0 35--><!DOCTYPE html><html lang=en><head><link href=//thumbs.ebaystatic.com rel=dns-prefetch><link href=//vi.vipr.ebaydesc.com rel=dns-prefetch><link href=//p.ebaystatic.com rel=dns-prefetch><link href=//thumbs.ebaystatic.com rel=dns-prefetch><link href=//q.ebaystatic.com rel=dns-prefetch><link href=//pics.ebaystatic.com rel=dns-prefetch><link href=//srx.main.ebayrtm.com rel=dns-prefetch><link href=//reco.ebay.com rel=dns-prefetch><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();</script><!--M^s0-35-4 s0-35 4--><noscript></noscript><!--M/--><script type="text/javascript"  data-inlinepayload={"loggerProps":{"serviceName":"r1vinode","serviceConsumerId":"urn:ebay-marketplace-consumerid:31be3645-70d4-467d-a381-1d97473133f4","serviceVersion":"r1vinode-0.0.4_20250416182756
# ...

# %%
data =r.text
print(data)
# Out:
# <!--M#s0--><!--M^s0-35 s0 35--><!DOCTYPE html><html lang=en><head><link href=//thumbs.ebaystatic.com rel=dns-prefetch><link href=//vi.vipr.ebaydesc.com rel=dns-prefetch><link href=//p.ebaystatic.com rel=dns-prefetch><link href=//thumbs.ebaystatic.com rel=dns-prefetch><link href=//q.ebaystatic.com rel=dns-prefetch><link href=//pics.ebaystatic.com rel=dns-prefetch><link href=//srx.main.ebayrtm.com rel=dns-prefetch><link href=//reco.ebay.com rel=dns-prefetch><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();</script><!--M^s0-35-4 s0-35 4--><noscript></noscript><!--M/--><script type="text/javascript"  data-inlinepayload={"loggerProps":{"serviceName":"r1vinode","serviceConsumerId":"urn:ebay-marketplace-consumerid:31be3645-70d4-467d-a381-1d97473133f4","serviceVersion":"r1vinode-0.0.4_2025041618275655
# ...

# %%
soup = BeautifulSoup(data,'html.parser')
titles = soup.find_all('h1')
for title in titles:
    print(title.text)
# Out:
# Sony PlayStation 5 Disc Edition Console 825GB- Good w/ Controller/HDMI/Cord

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!--M#s0-->
# <!--M^s0-35 s0 35-->
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>
#   <link href="//p.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//q.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>
#   <link href="//reco.ebay.com" rel="dns-prefetch"/>
#   <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#   <link href="//rover.ebay.com" rel="dns-prefetch"/>
#   <script>
#    $ssgST=new Date().getTime();
#   </script>
#   <!--M^s0-35-4 s0-35 4-->
#   <noscript>
#   </noscript>
#   <!--M/-->
# ...

# %%
ratings = soup.find_all('div', class_='fdbk-seller-rating__details')

if ratings:
        rating_details = rating.find_all('div', class_="fdbk-seller-rating__detailed-list")
        for detail in rating_details:

            rating_details = rating.find_all('div', class_="fdbk-detail-seller-rating")
            for detail in rating_details:
                rating_name = detail.find('div', class_='fdbk-detail-seller-rating__label')
                if rating_name:
                    rating_name = rating_name.get_text(strip=True)

                rating_value = detail.find('span', class_='fdbk-detail-seller-rating__value')
                if rating_value:
                    rating_value = rating_value.get_text(strip=True)

                print(f"Rating Name: {rating_name if rating_name else 'Not found'}")
                print(f"Rating Value: {rating_value if rating_value else 'Not found'} out of 5")

else:
    print("No reviews found on this page.")
# Out:
# Rating Name: Accurate description
# Rating Value: 4.8 out of 5
# Rating Name: Reasonable shipping cost
# Rating Value: 4.8 out of 5
# Rating Name: Shipping speed
# Rating Value: 4.9 out of 5
# Rating Name: Communication
# Rating Value: 4.8 out of 5

# %%
reviews = soup.find_all('ul', class_='fdbk-detail-list__cards')

if reviews:
        review_items = review_list.find_all('li')
        for review in review_items:
            print("Review Text:", review.get_text(strip=True))
            print("")
else:
    print("No reviews found on this page.")
# Out:
# Review Text: 2***r (164)- Feedback left by buyer.Past 6 monthsVerified purchaseGreat service! The seller shipped my item the next morning and I received it the following day. The item was well packaged and arrived as described. Thanks!ASUS RT-AX86S DualBand 4 Port Gaming Router - Black (#196817506684)
#
# Review Text: c***e (951)- Feedback left by buyer.Past 6 monthsVerified purchaseReceived item as described, functional with no issues, securely packaged and double boxed, shipped same day. Thank you!Alienware m17 R5 AMD Ryzen 9 6900HX AMD Radeon RX 6850M XT 12GB 32GB RAM 1TB SSD (#197047860533)
#
# Review Text: m***8 (134)- Feedback left by buyer.Past 6 monthsVerified purchaseGood seller good packaging fast deliveryDell Latitude E6230 Intel i5-3320M 2.6GHz 8GB RAM 256GB SSD OS Windows 10 Pro (#197019324130)
#
# ...
